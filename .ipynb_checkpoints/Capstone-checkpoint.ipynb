# %% [markdown]
# # AI-Based Forest Fire & Smoke Detection
#
# ## Capstone Project
#
# This project focuses on detecting forest fire and smoke regions from aerial imagery
# using machine learning on extracted spectral, intensity, and texture-based features.
# The objective is to build an end-to-end pipeline for fire risk prediction and spatial
# risk analysis to support drone-based disaster response.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve
from sklearn.ensemble import RandomForestClassifier

# For better plots
plt.style.use("seaborn-v0_8")
